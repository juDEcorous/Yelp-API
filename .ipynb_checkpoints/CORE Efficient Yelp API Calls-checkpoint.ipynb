# %% [markdown]
# # Efficient Yelp API Calls (Core)
#
# For this assignment, you will be working with the Yelp API.
#
# As before, you will use the Yelp API to search your favorite city for a cuisine type of your choice.
#
# Extract all of the results from your search and compile them into one dataframe using a for loop as shown in the lesson "Code for Efficient API Extraction"
#
# Save your notebook, commit the change to your repository and submit the repository URL for this assignment.

# %%
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook
import json, math, time, os
# json - for json files
# math - round up results
# time - shourt pause to not overwhelm server
# os - saving and loading files
import pandas as pd

# %%
with open('/Users/j29ma/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s = 5.0)
yelp_api

# %% [markdown]
# ## Search Terms and File Paths

# %%
# define location and term
location = 'Los Angeles, California'
term = 'Shabu Shabu'

# %%
split = location.split(',')[0]
split
# Out:
# 'Los Angeles'

# %%
# specify folder to save data
FOLDER = 'Data/'

# make folder
os.makedirs(FOLDER, exist_ok = True)

# specify JSON_FILE filename to save results
JSON_FILE = FOLDER+f'{split}_{term}.json'
JSON_FILE
# Out:
# 'Data/Los Angeles_Shabu Shabu.json'

# %% [markdown]
# ## Check if JSON file exists and Create if it does not

# %%
# check if JSON_FILE exist
file_exists = os.path.isfile(JSON_FILE)

# if it does not exists
if file_exists == False:
    # create folder
    folder = os.path.dirname(JSON_FILE)
    
    # if JSON_FILE included a folder:
    if len(folder) > 0:
        # create folder
        os.makedirs(folder, exist_ok = True)
    # inform user and save empty list
    print(f'[i] {JSON_FILE} not found. Saving empty list to file')
    #save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)

# if it dies exists
else:
    print(f'[i] {JSON_FILE} already exist')
# Out:
# [i] Data/Los Angeles_Shabu Shabu.json already exist

# %% [markdown]
# ## Make the first API call to get the first page to data

# %%
results = yelp_api.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['region']
# Out:
# {'center': {'longitude': -118.41064453125, 'latitude': 34.02010806957986}}

# %%
results['total']
# Out:
# 576

# %%
results['businesses']
# Out:
# [{'id': 'tGusz6xqBBABc1awGP1aLA',
#   'alias': 'shabuya-los-angeles-2',
#   'name': 'Shabuya',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Iry_2AEmQf3VCQSFY7PqXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shabuya-los-angeles-2?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 925,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.05156, 'longitude': -118.278207},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1925 W Olympic Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Los Angeles',
#    'zip_code': '90006',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1925 W Olympic Blvd', 'Los Angeles, CA 90006']},
#   'phone': '+12133185635',
#   'display_phone': '(213) 318-5635',
#   'distance': 12694.795396669433},
#  {'id': 'A0pgVbh53BPoqJUPRwx4ZA',
#   'alias': 'bon-shabu-los-angeles-5',
#   'name': 'Bon Shabu',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s-tAz2esb9x9G-5aEfuFCw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bon-shabu-los-angeles-5?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 133,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0613422, 'longitude': -118.2997235},
#   'transactions': ['restaurant_reservation'],
#   'location': {'address1': '3454 Wilshire Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90010',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3454 Wilshire Blvd', 'Los Angeles, CA 90010']},
#   'phone': '+12133185004',
#   'display_phone': '(213) 318-5004',
#   'distance': 11201.847843890306},
#  {'id': '32Wd-O6flvq5vzyUaerX9A',
#   'alias': 'aki-shabu-ktown-los-angeles-2',
#   'name': 'Aki Shabu Ktown',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JJBt3XETfq11mYWH4AfTVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aki-shabu-ktown-los-angeles-2?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 91,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.062775332045454,
#    'longitude': -118.3094757668648},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '621 S Western Ave 301',
#    'address2': 'Ste 301',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90005',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['621 S Western Ave 301',
#     'Ste 301',
#     'Los Angeles, CA 90005']},
#   'phone': '+12135294011',
#   'display_phone': '(213) 529-4011',
#   'distance': 10459.5596991732},
#  {'id': 'v9RZZLxE39Zx9L0mXB8kww',
#   'alias': 'shabu-shabu-house-los-angeles',
#   'name': 'Shabu Shabu House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rlXR7ZrM0vLWoDahqiq7MQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shabu-shabu-house-los-angeles?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 1462,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.049034, 'longitude': -118.240347},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '127 Japanese Village Plaza Mall',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90012',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['127 Japanese Village Plaza Mall',
#     'Los Angeles, CA 90012']},
#   'phone': '+12136803890',
#   'display_phone': '(213) 680-3890',
#   'distance': 16017.032627925804},
#  {'id': '7BZjZLN-YDmFb4Y3N-3aJw',
#   'alias': 'shabushi-los-angeles',
#   'name': 'ShaBuShi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YI0_NIVnFJt6ncWzMKs_Cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shabushi-los-angeles?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 538,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0982549, 'longitude': -118.3028954},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5185 Sunset Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5185 Sunset Blvd', 'Los Angeles, CA 90027']},
#   'phone': '+13235226457',
#   'display_phone': '(323) 522-6457',
#   'distance': 13209.536436674645},
#  {'id': 'rfVUBEy2i9aHsKjsJbqZwA',
#   'alias': 'haidilao-hot-pot-century-city-los-angeles',
#   'name': 'Haidilao Hot Pot Century City',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mLdfJrVCGNZ_vfiu6WXnXA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/haidilao-hot-pot-century-city-los-angeles?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 731,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.058799, 'longitude': -118.41932},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'location': {'address1': '10250 Santa Monica Blvd',
#    'address2': 'Ste 2610',
#    'address3': None,
#    'city': 'Los Angeles',
#    'zip_code': '90067',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['10250 Santa Monica Blvd',
#     'Ste 2610',
#     'Los Angeles, CA 90067']},
#   'phone': '+14243821234',
#   'display_phone': '(424) 382-1234',
#   'distance': 4390.768236227777},
#  {'id': 'KyppDi1Hdg2G1F_No30Bpw',
#   'alias': 'mizu-212-los-angeles',
#   'name': 'Mizu 212',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EbvMKt_tu6WFUQoagYKGRg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mizu-212-los-angeles?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 640,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 34.0409879964362,
#    'longitude': -118.443474060822},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '2000 Sawtelle Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90025',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2000 Sawtelle Blvd', 'Los Angeles, CA 90025']},
#   'phone': '+13102352120',
#   'display_phone': '(310) 235-2120',
#   'distance': 3813.509707775789},
#  {'id': 'BPgbSNw9tPUSaZpuhjVgfA',
#   'alias': 'joon-shabu-shabu-glendale-3',
#   'name': 'Joon Shabu Shabu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f0YIH8zcZXyZTBssbOygxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joon-shabu-shabu-glendale-3?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 1274,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.14611, 'longitude': -118.2528},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '220 E Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Glendale',
#    'zip_code': '91205',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['220 E Broadway', 'Glendale, CA 91205']},
#   'phone': '+18184845552',
#   'display_phone': '(818) 484-5552',
#   'distance': 20189.44577423731},
#  {'id': '91-q3tw6-zBrIH2Tvgf6ow',
#   'alias': 'momo-paradise-torrance',
#   'name': 'Momo Paradise',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QtXWPPFzIPUczjlYu_H8wA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/momo-paradise-torrance?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 1084,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.832087, 'longitude': -118.309605},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '21641 S Western Ave',
#    'address2': 'Unit A',
#    'address3': None,
#    'city': 'Torrance',
#    'zip_code': '90501',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['21641 S Western Ave', 'Unit A', 'Torrance, CA 90501']},
#   'phone': '+13107813052',
#   'display_phone': '(310) 781-3052',
#   'distance': 22889.22883603306},
#  {'id': '_8Tvjpgu56ioJf0ohHzUUg',
#   'alias': 'seoul-garden-restaurant-los-angeles',
#   'name': 'Seoul Garden Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w9xDfmzHnkixqBe8PCgYEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/seoul-garden-restaurant-los-angeles?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 586,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0507689, 'longitude': -118.2772433},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1833 W Olympic Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90006',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1833 W Olympic Blvd', 'Los Angeles, CA 90006']},
#   'phone': '+12133868477',
#   'display_phone': '(213) 386-8477',
#   'distance': 12756.447343901904},
#  {'id': 'G8l3nCG8TucrXc-REjmmTA',
#   'alias': 'broth-shabu-shabu-cerritos',
#   'name': 'Broth Shabu-Shabu',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dUwy8u3_lUmO9hYgNhS4-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/broth-shabu-shabu-cerritos?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 3093,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.867262, 'longitude': -118.094267},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '11221 183rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'Cerritos',
#    'zip_code': '90703',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['11221 183rd St', 'Cerritos, CA 90703']},
#   'phone': '+15624028828',
#   'display_phone': '(562) 402-8828',
#   'distance': 33772.55414155337},
#  {'id': 'HDCgzDgUYzkMGHxGj3W-QQ',
#   'alias': 'shin-sen-gumi-shabu-shabu-dining-gardena-gardena',
#   'name': 'Shin-Sen-Gumi Shabu Shabu Dining Gardena',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tBQUP-j2Z35F6cWXTnthMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shin-sen-gumi-shabu-shabu-dining-gardena-gardena?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 752,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.873362, 'longitude': -118.306609},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1695 W Artesia Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Gardena',
#    'zip_code': '90248',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1695 W Artesia Blvd', 'Gardena, CA 90248']},
#   'phone': '+13106492904',
#   'display_phone': '(310) 649-2904',
#   'distance': 18930.136331944435},
#  {'id': 'TqvFA-KXKZm91y9GOPsZCQ',
#   'alias': 'aki-shabu-n-hollywood',
#   'name': 'AKI Shabu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zBuklRIGygCc6VZ9BP92vw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aki-shabu-n-hollywood?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 370,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.1716757, 'longitude': -118.3700036},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '5560 Vineland Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'N Hollywood',
#    'zip_code': '91601',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5560 Vineland Ave', 'N Hollywood, CA 91601']},
#   'phone': '+18189853777',
#   'display_phone': '(818) 985-3777',
#   'distance': 17264.005399832342},
#  {'id': 'c3a-aJplogD8y00CH2fMsA',
#   'alias': 'ishabu-shabu-redondo-beach',
#   'name': 'IShabu Shabu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eCiF-FpeAcp0x_B3Hztp9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ishabu-shabu-redondo-beach?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 396,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.82381, 'longitude': -118.38498},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1212 S Pacific Coast Hwy',
#    'address2': 'Ste 200',
#    'address3': '',
#    'city': 'Redondo Beach',
#    'zip_code': '90277',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1212 S Pacific Coast Hwy',
#     'Ste 200',
#     'Redondo Beach, CA 90277']},
#   'phone': '+13105405846',
#   'display_phone': '(310) 540-5846',
#   'distance': 21951.480088914384},
#  {'id': '0Xbp0JMVujAHtQR2xTKBQA',
#   'alias': 'mikiya-wagyu-shabu-house-temple-city',
#   'name': 'Mikiya Wagyu Shabu House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-fbQPMVcZi7PvUa10reApQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mikiya-wagyu-shabu-house-temple-city?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 357,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.104631, 'longitude': -118.073221},
#   'transactions': [],
#   'location': {'address1': '5728 Rosemead Blvd',
#    'address2': 'Ste 107',
#    'address3': '',
#    'city': 'Temple City',
#    'zip_code': '91780',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5728 Rosemead Blvd',
#     'Ste 107',
#     'Temple City, CA 91780']},
#   'phone': '+16266588998',
#   'display_phone': '(626) 658-8998',
#   'distance': 32471.90767533457},
#  {'id': 'iRln878nbJK3IsJKbsP4KA',
#   'alias': 'boiling-pot-and-boba-street-northridge-2',
#   'name': 'Boiling Pot and Boba Street',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1WA_hPqeEROpuDgb5FFakA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boiling-pot-and-boba-street-northridge-2?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 209,
#   'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.23443311554991,
#    'longitude': -118.55891500236692},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '19524 Nordhoff St',
#    'address2': 'Ste 3',
#    'address3': '',
#    'city': 'Northridge',
#    'zip_code': '91324',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['19524 Nordhoff St', 'Ste 3', 'Northridge, CA 91324']},
#   'phone': '+17472065013',
#   'display_phone': '(747) 206-5013',
#   'distance': 27463.00722296869},
#  {'id': 'HmbZNTSG0HTWralCGpX9Kg',
#   'alias': 'osawa-shabu-shabu-and-sushi-pasadena',
#   'name': 'Osawa Shabu Shabu & Sushi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HEbOxXCUyL7C4BHJkriqtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/osawa-shabu-shabu-and-sushi-pasadena?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 1580,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.14724513644244,
#    'longitude': -118.14902605643655},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '77 N Raymond Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Pasadena',
#    'zip_code': '91103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['77 N Raymond Ave', 'Pasadena, CA 91103']},
#   'phone': '+16266831150',
#   'display_phone': '(626) 683-1150',
#   'distance': 27934.686536968165},
#  {'id': 'fnJSBd4BkxAt80iCpMhWCg',
#   'alias': 'nabemono-shabu-shabu-alhambra',
#   'name': 'Nabemono Shabu Shabu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SbnNjfb8jHtCP2pyVkYjZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nabemono-shabu-shabu-alhambra?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 380,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.095695, 'longitude': -118.126433},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '27 E Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Alhambra',
#    'zip_code': '91801',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['27 E Main St', 'Alhambra, CA 91801']},
#   'phone': '+16267034439',
#   'display_phone': '(626) 703-4439',
#   'distance': 27498.040296883457},
#  {'id': 'GRAQi7JGcpFRbSC_A4NApw',
#   'alias': 'tabu-shabu-thousand-oaks-thousand-oaks',
#   'name': 'Tabu Shabu Thousand Oaks',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qjnQOVRcs1uSw-aJ1UWyDw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tabu-shabu-thousand-oaks-thousand-oaks?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 362,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'diyfood', 'title': 'Do-It-Yourself Food'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1702705, 'longitude': -118.83826283},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2920 Thousand Oaks Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Thousand Oaks',
#    'zip_code': '91362',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2920 Thousand Oaks Blvd', 'Thousand Oaks, CA 91362']},
#   'phone': '+18053718228',
#   'display_phone': '(805) 371-8228',
#   'distance': 42764.323280053395},
#  {'id': 't8OWDBTwta52zkXng3HSLw',
#   'alias': 'o-seyo-shabu-shabu-pasadena',
#   'name': "O'seyo Shabu Shabu",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d2-G9OS9W_U8Dr2qER7pDg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-seyo-shabu-shabu-pasadena?adjust_creative=u67t0z_UFGQjtCvI1hRZUg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u67t0z_UFGQjtCvI1hRZUg',
#   'review_count': 930,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1462172567844,
#    'longitude': -118.090960085392},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2879 E Colorado Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Pasadena',
#    'zip_code': '91107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2879 E Colorado Blvd', 'Pasadena, CA 91107']},
#   'phone': '+16268440150',
#   'display_phone': '(626) 844-0150',
#   'distance': 32610.027158054647}]

# %% [markdown]
# ### How many results in total?

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                             alias  \
# 0   tGusz6xqBBABc1awGP1aLA                             shabuya-los-angeles-2
# 1   A0pgVbh53BPoqJUPRwx4ZA                           bon-shabu-los-angeles-5
# 2   32Wd-O6flvq5vzyUaerX9A                     aki-shabu-ktown-los-angeles-2
# 3   v9RZZLxE39Zx9L0mXB8kww                     shabu-shabu-house-los-angeles
# 4   7BZjZLN-YDmFb4Y3N-3aJw                              shabushi-los-angeles
# 5   rfVUBEy2i9aHsKjsJbqZwA         haidilao-hot-pot-century-city-los-angeles
# 6   KyppDi1Hdg2G1F_No30Bpw                              mizu-212-los-angeles
# 7   BPgbSNw9tPUSaZpuhjVgfA                       joon-shabu-shabu-glendale-3
# 8   91-q3tw6-zBrIH2Tvgf6ow                            momo-paradise-torrance
# 9   _8Tvjpgu56ioJf0ohHzUUg               seoul-garden-restaurant-los-angeles
# 10  G8l3nCG8TucrXc-REjmmTA                        broth-shabu-shabu-cerritos
# 11  HDCgzDgUYzkMGHxGj3W-QQ  shin-sen-gumi-shabu-shabu-dining-gardena-gardena
# 12  TqvFA-KXKZm91y9GOPsZCQ                             aki-shabu-n-hollywood
# 13  c3a-aJplogD8y00CH2fMsA                        ishabu-shabu-redondo-beach
# 14  0Xbp0JMVujAHtQR2xTKBQA              mikiya-wagyu-shabu-house-temple-city
# 15  iRln878nbJK3IsJKbsP4KA          boiling-pot-and-boba-street-northridge-2
# 16  HmbZNTSG0HTWralCGpX9Kg              osawa-shabu-shabu-and-sushi-pasadena
# 17  fnJSBd4BkxAt80iCpMhWCg                     nabemono-shabu-shabu-alhambra
# 18  GRAQi7JGcpFRbSC_A4NApw            tabu-shabu-thousand-oaks-thousand-oaks
# 19  t8OWDBTwta52zkXng3HSLw                       o-seyo-shabu-shabu-pasadena
#
#                                         name  \
# 0                                    Shabuya
# 1                                  Bon Shabu
# 2                            Aki Shabu Ktown
# 3                          Shabu Shabu House
# 4                                   ShaBuShi
# 5              Haidilao Hot Pot Century City
# 6                                   Mizu 212
# 7                           Joon Shabu Shabu
# 8                              Momo Paradise
# 9                    Seoul Garden Restaurant
# 10                         Broth Shabu-Shabu
# 11  Shin-Sen-Gumi Shabu Shabu Dining Gardena
# 12                                 AKI Shabu
# 13                              IShabu Shabu
# 14                  Mikiya Wagyu Shabu House
# 15               Boiling Pot and Boba Street
# 16                 Osawa Shabu Shabu & Sushi
# 17                      Nabemono Shabu Shabu
# 18                  Tabu Shabu Thousand Oaks
# 19                        O'seyo Shabu Shabu
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/Iry_2A...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/s-tAz2...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/JJBt3X...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/rlXR7Z...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/YI0_NI...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/mLdfJr...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/EbvMKt...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/f0YIH8...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/QtXWPP...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/w9xDfm...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/dUwy8u...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/tBQUP-...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/zBuklR...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/eCiF-F...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/-fbQPM...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/1WA_hP...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/HEbOxX...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/SbnNjf...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/qjnQOV...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/d2-G9O...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/shabuya-los-angeles-2...           925
# 1   https://www.yelp.com/biz/bon-shabu-los-angeles...           133
# 2   https://www.yelp.com/biz/aki-shabu-ktown-los-a...            91
# 3   https://www.yelp.com/biz/shabu-shabu-house-los...          1462
# 4   https://www.yelp.com/biz/shabushi-los-angeles?...           538
# 5   https://www.yelp.com/biz/haidilao-hot-pot-cent...           731
# 6   https://www.yelp.com/biz/mizu-212-los-angeles?...           640
# 7   https://www.yelp.com/biz/joon-shabu-shabu-glen...          1274
# 8   https://www.yelp.com/biz/momo-paradise-torranc...          1084
# 9   https://www.yelp.com/biz/seoul-garden-restaura...           586
# 10  https://www.yelp.com/biz/broth-shabu-shabu-cer...          3093
# 11  https://www.yelp.com/biz/shin-sen-gumi-shabu-s...           752
# 12  https://www.yelp.com/biz/aki-shabu-n-hollywood...           370
# 13  https://www.yelp.com/biz/ishabu-shabu-redondo-...           396
# 14  https://www.yelp.com/biz/mikiya-wagyu-shabu-ho...           357
# 15  https://www.yelp.com/biz/boiling-pot-and-boba-...           209
# 16  https://www.yelp.com/biz/osawa-shabu-shabu-and...          1580
# 17  https://www.yelp.com/biz/nabemono-shabu-shabu-...           380
# 18  https://www.yelp.com/biz/tabu-shabu-thousand-o...           362
# 19  https://www.yelp.com/biz/o-seyo-shabu-shabu-pa...           930
#
#                                            categories  rating  \
# 0   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1   [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.0
# 2           [{'alias': 'hotpot', 'title': 'Hot Pot'}]     4.5
# 3   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 4   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 5           [{'alias': 'hotpot', 'title': 'Hot Pot'}]     4.5
# 6   [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 7   [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.5
# 8   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 9   [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.0
# 10  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 11  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 12  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 13  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.5
# 14  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.5
# 15  [{'alias': 'tea', 'title': 'Tea Rooms'}, {'ali...     4.5
# 16  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 17  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 18  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 19  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
#
#                                           coordinates  \
# 0    {'latitude': 34.05156, 'longitude': -118.278207}
# 1   {'latitude': 34.0613422, 'longitude': -118.299...
# 2   {'latitude': 34.062775332045454, 'longitude': ...
# 3   {'latitude': 34.049034, 'longitude': -118.240347}
# 4   {'latitude': 34.0982549, 'longitude': -118.302...
# 5    {'latitude': 34.058799, 'longitude': -118.41932}
# 6   {'latitude': 34.0409879964362, 'longitude': -1...
# 7      {'latitude': 34.14611, 'longitude': -118.2528}
# 8   {'latitude': 33.832087, 'longitude': -118.309605}
# 9   {'latitude': 34.0507689, 'longitude': -118.277...
# 10  {'latitude': 33.867262, 'longitude': -118.094267}
# 11  {'latitude': 33.873362, 'longitude': -118.306609}
# 12  {'latitude': 34.1716757, 'longitude': -118.370...
# 13    {'latitude': 33.82381, 'longitude': -118.38498}
# 14  {'latitude': 34.104631, 'longitude': -118.073221}
# 15  {'latitude': 34.23443311554991, 'longitude': -...
# 16  {'latitude': 34.14724513644244, 'longitude': -...
# 17  {'latitude': 34.095695, 'longitude': -118.126433}
# 18  {'latitude': 34.1702705, 'longitude': -118.838...
# 19  {'latitude': 34.1462172567844, 'longitude': -1...
#
#                                   transactions price  \
# 0                                   [delivery]    $$
# 1                     [restaurant_reservation]   NaN
# 2                           [pickup, delivery]   $$$
# 3                                   [delivery]    $$
# 4                           [pickup, delivery]    $$
# 5   [restaurant_reservation, delivery, pickup]   NaN
# 6                           [pickup, delivery]   $$$
# 7                                   [delivery]    $$
# 8                           [pickup, delivery]    $$
# 9                           [pickup, delivery]    $$
# 10                                          []    $$
# 11                          [pickup, delivery]   $$$
# 12                          [pickup, delivery]   $$$
# 13                          [pickup, delivery]   $$$
# 14                                          []   NaN
# 15                                          []    $$
# 16                                  [delivery]    $$
# 17                          [pickup, delivery]    $$
# 18                          [pickup, delivery]    $$
# 19                          [pickup, delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': '1925 W Olympic Blvd', 'address2'...  +12133185635
# 1   {'address1': '3454 Wilshire Blvd', 'address2':...  +12133185004
# 2   {'address1': '621 S Western Ave 301', 'address...  +12135294011
# 3   {'address1': '127 Japanese Village Plaza Mall'...  +12136803890
# 4   {'address1': '5185 Sunset Blvd', 'address2': '...  +13235226457
# 5   {'address1': '10250 Santa Monica Blvd', 'addre...  +14243821234
# 6   {'address1': '2000 Sawtelle Blvd', 'address2':...  +13102352120
# 7   {'address1': '220 E Broadway', 'address2': '',...  +18184845552
# 8   {'address1': '21641 S Western Ave', 'address2'...  +13107813052
# 9   {'address1': '1833 W Olympic Blvd', 'address2'...  +12133868477
# 10  {'address1': '11221 183rd St', 'address2': '',...  +15624028828
# 11  {'address1': '1695 W Artesia Blvd', 'address2'...  +13106492904
# 12  {'address1': '5560 Vineland Ave', 'address2': ...  +18189853777
# 13  {'address1': '1212 S Pacific Coast Hwy', 'addr...  +13105405846
# 14  {'address1': '5728 Rosemead Blvd', 'address2':...  +16266588998
# 15  {'address1': '19524 Nordhoff St', 'address2': ...  +17472065013
# 16  {'address1': '77 N Raymond Ave', 'address2': '...  +16266831150
# 17  {'address1': '27 E Main St', 'address2': '', '...  +16267034439
# 18  {'address1': '2920 Thousand Oaks Blvd', 'addre...  +18053718228
# 19  {'address1': '2879 E Colorado Blvd', 'address2...  +16268440150
#
#      display_phone      distance
# 0   (213) 318-5635  12694.795397
# 1   (213) 318-5004  11201.847844
# 2   (213) 529-4011  10459.559699
# 3   (213) 680-3890  16017.032628
# 4   (323) 522-6457  13209.536437
# 5   (424) 382-1234   4390.768236
# 6   (310) 235-2120   3813.509708
# 7   (818) 484-5552  20189.445774
# 8   (310) 781-3052  22889.228836
# 9   (213) 386-8477  12756.447344
# 10  (562) 402-8828  33772.554142
# 11  (310) 649-2904  18930.136332
# 12  (818) 985-3777  17264.005400
# 13  (310) 540-5846  21951.480089
# 14  (626) 658-8998  32471.907675
# 15  (747) 206-5013  27463.007223
# 16  (626) 683-1150  27934.686537
# 17  (626) 703-4439  27498.040297
# 18  (805) 371-8228  42764.323280
# 19  (626) 844-0150  32610.027158

# %%
# results per page
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# number of pages
# math.ceil to round up for the total number of results
n_pages = math.ceil(results['total'] / results_per_page)
n_pages
# Out:
# 29

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\j29ma\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\j29ma\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %%
# get the rest of the data ( because we only have 20 results)
for i in tqdm_notebook(range(1, n_pages+1)):
    # block of code we want to try
    try:
        time.sleep(.2) # [!] need to know this
        # read results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        # save number of results for the use as offset
        n_results = len(previous_results)
        
        # use n_results as the OFFSET
        results = yelp_api.search_query(term = term, location = location,
                                       offset = n_results+1)
        
        #append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)
    # what to do on errors
    except Exception as e:
        print('[!] Error', e)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %% [markdown]
# ## Open the Final JSON file with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                      alias  \
# 0  A0pgVbh53BPoqJUPRwx4ZA                    bon-shabu-los-angeles-5
# 1  32Wd-O6flvq5vzyUaerX9A              aki-shabu-ktown-los-angeles-2
# 2  v9RZZLxE39Zx9L0mXB8kww              shabu-shabu-house-los-angeles
# 3  7BZjZLN-YDmFb4Y3N-3aJw                       shabushi-los-angeles
# 4  rfVUBEy2i9aHsKjsJbqZwA  haidilao-hot-pot-century-city-los-angeles
#
#                             name  \
# 0                      Bon Shabu
# 1                Aki Shabu Ktown
# 2              Shabu Shabu House
# 3                       ShaBuShi
# 4  Haidilao Hot Pot Century City
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/s-tAz2...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/JJBt3X...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/rlXR7Z...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/YI0_NI...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/mLdfJr...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/bon-shabu-los-angeles...           133
# 1  https://www.yelp.com/biz/aki-shabu-ktown-los-a...            91
# 2  https://www.yelp.com/biz/shabu-shabu-house-los...          1462
# 3  https://www.yelp.com/biz/shabushi-los-angeles?...           538
# 4  https://www.yelp.com/biz/haidilao-hot-pot-cent...           731
#
#                                           categories  rating  \
# 0  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.0
# 1          [{'alias': 'hotpot', 'title': 'Hot Pot'}]     4.5
# 2  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 3  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 4          [{'alias': 'hotpot', 'title': 'Hot Pot'}]     4.5
#
#                                          coordinates  \
# 0  {'latitude': 34.0613422, 'longitude': -118.299...
# 1  {'latitude': 34.062775332045454, 'longitude': ...
# 2  {'latitude': 34.049034, 'longitude': -118.240347}
# 3  {'latitude': 34.0982549, 'longitude': -118.302...
# 4   {'latitude': 34.058799, 'longitude': -118.41932}
#
#                                  transactions  \
# 0                    [restaurant_reservation]
# 1                          [pickup, delivery]
# 2                                  [delivery]
# 3                          [pickup, delivery]
# 4  [pickup, restaurant_reservation, delivery]
#
#                                             location         phone  \
# 0  {'address1': '3454 Wilshire Blvd', 'address2':...  +12133185004
# 1  {'address1': '621 S Western Ave 301', 'address...  +12135294011
# 2  {'address1': '127 Japanese Village Plaza Mall'...  +12136803890
# 3  {'address1': '5185 Sunset Blvd', 'address2': '...  +13235226457
# 4  {'address1': '10250 Santa Monica Blvd', 'addre...  +14243821234
#
#     display_phone      distance price
# 0  (213) 318-5004  11201.847844   NaN
# 1  (213) 529-4011  10459.559699   $$$
# 2  (213) 680-3890  16017.032628    $$
# 3  (323) 522-6457  13209.536437    $$
# 4  (424) 382-1234   4390.768236   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             575 non-null    object
#  1   alias          575 non-null    object
#  2   name           575 non-null    object
#  3   image_url      575 non-null    object
#  4   is_closed      575 non-null    bool
#  5   url            575 non-null    object
#  6   review_count   575 non-null    int64
#  7   categories     575 non-null    object
#  8   rating         575 non-null    float64
#  9   coordinates    575 non-null    object
#  10  transactions   575 non-null    object
#  11  location       575 non-null    object
#  12  phone          575 non-null    object
#  13  display_phone  575 non-null    object
#  14  distance       575 non-null    float64
#  15  price          546 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 68.1+ KB

# %%
# convert filename to a .csv.gz
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'Data/Los Angeles_Shabu Shabu.csv.gz'

# %%
# save as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
